# %% [markdown]
# <a href="https://colab.research.google.com/github/YeshayaG/MCON_141/blob/main/Data_Analysis_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("https://raw.githubusercontent.com/YeshayaG/MCON_141/main/colleges.csv",index_col=0)

# %% [markdown]
# This dataset contains the US News rankings of the best American universities of undergraduate programs. This is how US News ranks the colleges:
# "We calculated 10 distinct overall rankings where colleges and universities were grouped by their academic missions. For each ranking, the sum of weighted, normalized values across 17 indicators of academic quality determine each school's overall score and, by extension, its overall rank.
# The top performer(s) in each ranking displays an overall score of 100. Others' overall scores are on a 0-99 scale reflecting the distance from their ranking's top-performing school(s). Those placing outside the top 75% display their ranking's bottom quartile range (e.g., No. 90-120) instead of their individual ranks (e.g., No. 102)."

# %%
data.index = np.arange(1,len(data)+1)
data.index.name = "Rank"
data
# Out:
#                                College Name  Tuition  Enrollment Numbers
# Rank
# 1                      Princeton University    56010                4773
# 2                       Columbia University    63530                6170
# 3                        Harvard University    55587                5222
# 4     Massachusetts Institute of Technology    55878                4361
# 5                           Yale University    59950                4703
# ...                                     ...      ...                 ...
# 388                William Woods University    25930                 873
# 389                   Wilmington University    11750                9230
# 390                      Wingate University    40170                2683
# 391                 Wright State University    19097                8332
# 392                     Brandman University    15480                6114
#
# [392 rows x 3 columns]

# %%
data.dtypes
# Out:
# College Name          object
# Tuition                int64
# Enrollment Numbers     int64
# dtype: object

# %% [markdown]
# "This dataset contains the rankings of 392 American universities based on their undergraduate programs. It also contains the tuitions and enrollment numbers of each university. 2 colleges don't have tuition data, so it is labelled -1."

# %%
data[data["Tuition"]==-1]
# Out:
#                          College Name  Tuition  Enrollment Numbers
# Rank
# 358   University of Alaska--Fairbanks       -1                6206
# 360          University of Bridgeport       -1                3233

# %%
data.isna().sum()
# Out:
# College Name          0
# Tuition               0
# Enrollment Numbers    0
# dtype: int64

# %% [markdown]
# Since we dont have the tuition data for the University of Alaska--Fairbanks	and the University of Bridgeport in order to calculate the statistics of this data we will create another data set without these two colleges.

# %%
stat_copy = data[data["Tuition"]!=-1]

# %%
stat_copy["Tuition"].describe()
# Out:
# count      390.000000
# mean     33679.466667
# std      13895.141902
# min       4198.000000
# 25%      23148.000000
# 50%      31690.000000
# 75%      43497.500000
# max      63530.000000
# Name: Tuition, dtype: float64

# %%
data["Enrollment Numbers"].describe()
# Out:
# count      392.000000
# mean     12959.352041
# std      11645.263803
# min        249.000000
# 25%       4433.750000
# 50%       8826.000000
# 75%      18830.500000
# max      72485.000000
# Name: Enrollment Numbers, dtype: float64

# %% [markdown]
# We see a downward trending for tutition as rank goes down

# %%
stat_copy.plot(y="Tuition",figsize=(10,10))

# %%
data.plot(y="Enrollment Numbers",figsize=(10,10))

# %%
stat_copy.plot.scatter(x="Tuition",y="Enrollment Numbers")

# %% [markdown]
# We see through this data that
# 1)the schools with the highest enrollment numbers cost $20,000 - $40,000 a year.
# 2)we also see that as the rank of the college goes down so does the tuition for attending the college.
# 3)finally, enrollement numbers and rank arent so correlated.
